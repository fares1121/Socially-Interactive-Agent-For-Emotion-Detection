# %% [markdown]
# # **Emotion Detection Using CNN**

# %% [markdown]
# **Import Libraries**

# %%
from keras.utils import to_categorical
from keras_preprocessing.image import load_img
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D
import os
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
from sklearn.preprocessing import LabelEncoder
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, BatchNormalization
from keras.models import Sequential
from keras.regularizers import l2
from keras.models import load_model

# %% [markdown]
# **Load Datasets**

# %%
TRAIN_DIR = "./images/train"
TEST_DIR = "./images/validation"

# %%
def createdataframe(dir):
    image_paths = []
    labels = []
    for label in os.listdir(dir):
        for imagename in os.listdir(os.path.join(dir,label)):
            image_paths.append(os.path.join(dir,label,imagename))
            labels.append(label)
        print(label, "completed")
    return image_paths,labels

# %%
train = pd.DataFrame()
train['image'], train['label'] = createdataframe(TRAIN_DIR)
# Out:
# angry completed
# disgust completed
# fear completed
# happy completed
# neutral completed
# sad completed
# surprise completed

# %%
print(train)
# Out:
#                                   image     label
# 0            ./images/train\angry\0.jpg     angry
# 1            ./images/train\angry\1.jpg     angry
# 2           ./images/train\angry\10.jpg     angry
# 3        ./images/train\angry\10002.jpg     angry
# 4        ./images/train\angry\10016.jpg     angry
# ...                                 ...       ...
# 28816  ./images/train\surprise\9969.jpg  surprise
# 28817  ./images/train\surprise\9985.jpg  surprise
# 28818  ./images/train\surprise\9990.jpg  surprise
# 28819  ./images/train\surprise\9992.jpg  surprise
# 28820  ./images/train\surprise\9996.jpg  surprise
#
# [28821 rows x 2 columns]

# %%
test = pd.DataFrame()
test['image'], test['label'] = createdataframe(TEST_DIR)
# Out:
# angry completed
# disgust completed
# fear completed
# happy completed
# neutral completed
# sad completed
# surprise completed

# %%
print(test)
print(test['image'])
# Out:
#                                       image     label
# 0       ./images/validation\angry\10052.jpg     angry
# 1       ./images/validation\angry\10065.jpg     angry
# 2       ./images/validation\angry\10079.jpg     angry
# 3       ./images/validation\angry\10095.jpg     angry
# 4       ./images/validation\angry\10121.jpg     angry
# ...                                     ...       ...
# 7061  ./images/validation\surprise\9806.jpg  surprise
# 7062  ./images/validation\surprise\9830.jpg  surprise
# 7063  ./images/validation\surprise\9853.jpg  surprise
# 7064  ./images/validation\surprise\9878.jpg  surprise
# 7065   ./images/validation\surprise\993.jpg  surprise
#
# [7066 rows x 2 columns]
# 0         ./images/validation\angry\10052.jpg
# 1         ./images/validation\angry\10065.jpg
# 2         ./images/validation\angry\10079.jpg
# 3         ./images/validation\angry\10095.jpg
# 4         ./images/validation\angry\10121.jpg
#                         ...
# 7061    ./images/validation\surprise\9806.jpg
# 7062    ./images/validation\surprise\9830.jpg
# 7063    ./images/validation\surprise\9853.jpg
# 7064    ./images/validation\surprise\9878.jpg
# 7065     ./images/validation\surprise\993.jpg
# Name: image, Length: 7066, dtype: object

# %% [markdown]
# **Preprocess Data**

# %%
def extract_features(images):
    features = []
    for image in tqdm(images):
        img = load_img(image,grayscale =  True )
        img = np.array(img)
        features.append(img)
    features = np.array(features)
    features = features.reshape(len(features),48,48,1)
    return features

# %%
train_features = extract_features(train['image'])
# Out:
#   0%|          | 0/28821 [00:00<?, ?it/s]
# c:\Users\amamo\anaconda3\Lib\site-packages\keras_preprocessing\image\utils.py:107: UserWarning: grayscale is deprecated. Please use color_mode = "grayscale"
#   warnings.warn('grayscale is deprecated. Please use '

# %%
test_features = extract_features(test['image'])
# Out:
#   0%|          | 0/7066 [00:00<?, ?it/s]

# %%
x_train = train_features/255.0
x_test = test_features/255.0

# %%
le = LabelEncoder()
le.fit(train['label'])
# Out:
# LabelEncoder()

# %%
y_train = le.transform(train['label'])
y_test = le.transform(test['label'])

# %%
y_train = to_categorical(y_train,num_classes = 7)
y_test = to_categorical(y_test,num_classes = 7)

# %% [markdown]
# **Define Callbacks**

# %%
# Define callbacks
# Use .keras for checkpointing to avoid the error
checkpoint = ModelCheckpoint("./model.keras", monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)
reduce_learningrate = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, verbose=1, min_delta=0.0001)

callbacks_list = [checkpoint, early_stopping, reduce_learningrate]

# %% [markdown]
# **Define Model**

# %%
# Define your model
model = Sequential()

# Convolutional layers with Batch Normalization
model.add(Conv2D(128, kernel_size=(3,3), activation='relu', input_shape=(48,48,1)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(256, kernel_size=(3,3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, kernel_size=(3,3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, kernel_size=(3,3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Flatten())

# Fully connected layers with L2 Regularization
model.add(Dense(512, activation='relu', kernel_regularizer=l2(0.001)))
model.add(Dropout(0.4))
model.add(Dense(256, activation='relu', kernel_regularizer=l2(0.001)))
model.add(Dropout(0.3))

# Output layer
model.add(Dense(7, activation='softmax'))
# Out:
# c:\Users\amamo\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# **Compile Model**

# %%
# Compile the model with the Adam optimizer
model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# **Train Model**

# %%
# Fit the model
model.fit(x=x_train, y=y_train, batch_size=64, epochs=100, validation_data=(x_test, y_test), callbacks=callbacks_list)
# Out:
# Epoch 1/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 946ms/step - accuracy: 0.2868 - loss: 2.4987
# Epoch 1: val_accuracy improved from 0.28941 to 0.36994, saving model to ./model.keras
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 453s 1s/step - accuracy: 0.2868 - loss: 2.4986 - val_accuracy: 0.3699 - val_loss: 2.3441 - learning_rate: 1.0000e-04
# Epoch 2/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 950ms/step - accuracy: 0.3307 - loss: 2.3868
# Epoch 2: val_accuracy improved from 0.36994 to 0.39924, saving model to ./model.keras
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 458s 1s/step - accuracy: 0.3307 - loss: 2.3867 - val_accuracy: 0.3992 - val_loss: 2.2296 - learning_rate: 1.0000e-04
# Epoch 3/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 953ms/step - accuracy: 0.3697 - loss: 2.2737
# Epoch 3: val_accuracy improved from 0.39924 to 0.42669, saving model to ./model.keras
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 452s 1s/step - accuracy: 0.3697 - loss: 2.2737 - val_accuracy: 0.4267 - val_loss: 2.1388 - learning_rate: 1.0000e-04
# Epoch 4/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 931ms/step - accuracy: 0.3906 - loss: 2.1827
# Epoch 4: val_accuracy did not improve from 0.42669
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 448s 994ms/step - accuracy: 0.3906 - loss: 2.1827 - val_accuracy: 0.3855 - val_loss: 2.2051 - learning_rate: 1.0000e-04
# Epoch 5/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 879ms/step - accuracy: 0.4099 - loss: 2.0934
# Epoch 5: val_accuracy improved from 0.42669 to 0.44792, saving model to ./model.keras
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 427s 947ms/step - accuracy: 0.4099 - loss: 2.0934 - val_accuracy: 0.4479 - val_loss: 2.0087 - learning_rate: 1.0000e-04
# Epoch 6/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 946ms/step - accuracy: 0.4331 - loss: 2.0147
# Epoch 6: val_accuracy improved from 0.44792 to 0.47070, saving model to ./model.keras
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 454s 1s/step - accuracy: 0.4331 - loss: 2.0146 - val_accuracy: 0.4707 - val_loss: 1.9068 - learning_rate: 1.0000e-04
# Epoch 7/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 858ms/step - accuracy: 0.4505 - loss: 1.9356
# Epoch 7: val_accuracy improved from 0.47070 to 0.49731, saving model to ./model.keras
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 414s 920ms/step - accuracy: 0.4505 - loss: 1.9355 - val_accuracy: 0.4973 - val_loss: 1.8040 - learning_rate: 1.0000e-04
# Epoch 8/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step - accuracy: 0.4740 - loss: 1.8389
# Epoch 8: val_accuracy improved from 0.49731 to 0.52788, saving model to ./model.keras
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 204s 451ms/step - accuracy: 0.4740 - loss: 1.8388 - val_accuracy: 0.5279 - val_loss: 1.6896 - learning_rate: 1.0000e-04
# Epoch 9/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.4900 - loss: 1.7687
# Epoch 9: val_accuracy improved from 0.52788 to 0.53170, saving model to ./model.keras
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 180s 399ms/step - accuracy: 0.4900 - loss: 1.7687 - val_accuracy: 0.5317 - val_loss: 1.6514 - learning_rate: 1.0000e-04
# Epoch 10/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.5077 - loss: 1.7027
# Epoch 10: val_accuracy improved from 0.53170 to 0.53368, saving model to ./model.keras
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 181s 402ms/step - accuracy: 0.5077 - loss: 1.7027 - val_accuracy: 0.5337 - val_loss: 1.6080 - learning_rate: 1.0000e-04
# Epoch 11/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.5194 - loss: 1.6299
# Epoch 11: val_accuracy improved from 0.53368 to 0.55958, saving model to ./model.keras
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 179s 396ms/step - accuracy: 0.5194 - loss: 1.6299 - val_accuracy: 0.5596 - val_loss: 1.5299 - learning_rate: 1.0000e-04
# Epoch 12/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.5348 - loss: 1.5714
# Epoch 12: val_accuracy improved from 0.55958 to 0.56920, saving model to ./model.keras
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 178s 394ms/step - accuracy: 0.5348 - loss: 1.5714 - val_accuracy: 0.5692 - val_loss: 1.4808 - learning_rate: 1.0000e-04
# Epoch 13/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.5461 - loss: 1.5285
# Epoch 13: val_accuracy improved from 0.56920 to 0.57402, saving model to ./model.keras
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 175s 389ms/step - accuracy: 0.5461 - loss: 1.5285 - val_accuracy: 0.5740 - val_loss: 1.4291 - learning_rate: 1.0000e-04
# Epoch 14/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.5471 - loss: 1.4937
# Epoch 14: val_accuracy did not improve from 0.57402
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 175s 388ms/step - accuracy: 0.5471 - loss: 1.4937 - val_accuracy: 0.5603 - val_loss: 1.4422 - learning_rate: 1.0000e-04
# Epoch 15/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step - accuracy: 0.5647 - loss: 1.4390
# Epoch 15: val_accuracy improved from 0.57402 to 0.57515, saving model to ./model.keras
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 194s 431ms/step - accuracy: 0.5647 - loss: 1.4390 - val_accuracy: 0.5751 - val_loss: 1.3977 - learning_rate: 1.0000e-04
# Epoch 16/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.5669 - loss: 1.4048
# Epoch 16: val_accuracy improved from 0.57515 to 0.58704, saving model to ./model.keras
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 181s 400ms/step - accuracy: 0.5669 - loss: 1.4048 - val_accuracy: 0.5870 - val_loss: 1.3492 - learning_rate: 1.0000e-04
# Epoch 17/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.5786 - loss: 1.3609
# Epoch 17: val_accuracy did not improve from 0.58704
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 178s 394ms/step - accuracy: 0.5786 - loss: 1.3609 - val_accuracy: 0.5846 - val_loss: 1.3287 - learning_rate: 1.0000e-04
# Epoch 18/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.5885 - loss: 1.3226
# Epoch 18: val_accuracy did not improve from 0.58704
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 179s 396ms/step - accuracy: 0.5885 - loss: 1.3226 - val_accuracy: 0.5849 - val_loss: 1.3393 - learning_rate: 1.0000e-04
# Epoch 19/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.5923 - loss: 1.2930
# Epoch 19: val_accuracy improved from 0.58704 to 0.60416, saving model to ./model.keras
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 180s 398ms/step - accuracy: 0.5923 - loss: 1.2930 - val_accuracy: 0.6042 - val_loss: 1.2683 - learning_rate: 1.0000e-04
# Epoch 20/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.6031 - loss: 1.2454
# Epoch 20: val_accuracy did not improve from 0.60416
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 179s 397ms/step - accuracy: 0.6031 - loss: 1.2454 - val_accuracy: 0.5771 - val_loss: 1.3272 - learning_rate: 1.0000e-04
# Epoch 21/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 541ms/step - accuracy: 0.6087 - loss: 1.2260
# Epoch 21: val_accuracy improved from 0.60416 to 0.60643, saving model to ./model.keras
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 268s 594ms/step - accuracy: 0.6087 - loss: 1.2260 - val_accuracy: 0.6064 - val_loss: 1.2444 - learning_rate: 1.0000e-04
# Epoch 22/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 777ms/step - accuracy: 0.6142 - loss: 1.2010
# Epoch 22: val_accuracy improved from 0.60643 to 0.61067, saving model to ./model.keras
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 374s 828ms/step - accuracy: 0.6142 - loss: 1.2010 - val_accuracy: 0.6107 - val_loss: 1.2247 - learning_rate: 1.0000e-04
# Epoch 23/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 766ms/step - accuracy: 0.6258 - loss: 1.1666
# Epoch 23: val_accuracy improved from 0.61067 to 0.62114, saving model to ./model.keras
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 368s 815ms/step - accuracy: 0.6258 - loss: 1.1667 - val_accuracy: 0.6211 - val_loss: 1.1982 - learning_rate: 1.0000e-04
# Epoch 24/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 761ms/step - accuracy: 0.6313 - loss: 1.1392
# Epoch 24: val_accuracy did not improve from 0.62114
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 365s 808ms/step - accuracy: 0.6313 - loss: 1.1392 - val_accuracy: 0.6152 - val_loss: 1.2106 - learning_rate: 1.0000e-04
# Epoch 25/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 767ms/step - accuracy: 0.6418 - loss: 1.1032
# Epoch 25: val_accuracy did not improve from 0.62114
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 370s 820ms/step - accuracy: 0.6418 - loss: 1.1032 - val_accuracy: 0.6156 - val_loss: 1.1969 - learning_rate: 1.0000e-04
# Epoch 26/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 825ms/step - accuracy: 0.6501 - loss: 1.0804
# Epoch 26: val_accuracy improved from 0.62114 to 0.62213, saving model to ./model.keras
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 401s 888ms/step - accuracy: 0.6501 - loss: 1.0804 - val_accuracy: 0.6221 - val_loss: 1.1797 - learning_rate: 1.0000e-04
# Epoch 27/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 918ms/step - accuracy: 0.6581 - loss: 1.0590
# Epoch 27: val_accuracy did not improve from 0.62213
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 435s 965ms/step - accuracy: 0.6580 - loss: 1.0590 - val_accuracy: 0.6197 - val_loss: 1.1708 - learning_rate: 1.0000e-04
# Epoch 28/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 889ms/step - accuracy: 0.6628 - loss: 1.0354
# Epoch 28: val_accuracy improved from 0.62213 to 0.62525, saving model to ./model.keras
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 422s 937ms/step - accuracy: 0.6628 - loss: 1.0354 - val_accuracy: 0.6252 - val_loss: 1.1624 - learning_rate: 1.0000e-04
# Epoch 29/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 836ms/step - accuracy: 0.6752 - loss: 1.0037
# Epoch 29: val_accuracy improved from 0.62525 to 0.62539, saving model to ./model.keras
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 407s 902ms/step - accuracy: 0.6752 - loss: 1.0037 - val_accuracy: 0.6254 - val_loss: 1.1576 - learning_rate: 1.0000e-04
# Epoch 30/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 937ms/step - accuracy: 0.6827 - loss: 0.9842
# Epoch 30: val_accuracy did not improve from 0.62539
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 451s 999ms/step - accuracy: 0.6827 - loss: 0.9842 - val_accuracy: 0.5920 - val_loss: 1.2329 - learning_rate: 1.0000e-04
# Epoch 31/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 909ms/step - accuracy: 0.6835 - loss: 0.9697
# Epoch 31: val_accuracy improved from 0.62539 to 0.62978, saving model to ./model.keras
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 441s 977ms/step - accuracy: 0.6835 - loss: 0.9697 - val_accuracy: 0.6298 - val_loss: 1.1375 - learning_rate: 1.0000e-04
# Epoch 32/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 913ms/step - accuracy: 0.6988 - loss: 0.9293
# Epoch 32: val_accuracy did not improve from 0.62978
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 441s 978ms/step - accuracy: 0.6988 - loss: 0.9293 - val_accuracy: 0.6162 - val_loss: 1.1812 - learning_rate: 1.0000e-04
# Epoch 33/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 790ms/step - accuracy: 0.7014 - loss: 0.9220
# Epoch 33: val_accuracy did not improve from 0.62978
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 379s 841ms/step - accuracy: 0.7014 - loss: 0.9220 - val_accuracy: 0.6269 - val_loss: 1.1577 - learning_rate: 1.0000e-04
# Epoch 34/100
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 791ms/step - accuracy: 0.7099 - loss: 0.8876
# Epoch 34: val_accuracy improved from 0.62978 to 0.63133, saving model to ./model.keras
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 379s 840ms/step - accuracy: 0.7099 - loss: 0.8876 - val_accuracy: 0.6313 - val_loss: 1.1536 - learning_rate: 1.0000e-04
# Epoch 34: early stopping
# Restoring model weights from the end of the best epoch: 31.

# %% [markdown]
# **Load Model and Weights**

# %%
model = load_model("./model.keras")

# %%
model.save_weights("./emotiondetector_weights.weights.h5")

# %%
model.load_weights("./emotiondetector_weights.weights.h5")
